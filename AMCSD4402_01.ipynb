# %%
a = float(input("Enter first number: "))
operator = input("Enter operator (+, -, *, /): ")
b = float(input("Enter second number: "))

if operator == "+":
    print("Result =", a + b)

elif operator == "-":
    print("Result =", a - b)

elif operator == "*":
    print("Result =", a * b)

elif operator == "/":
    if b != 0:
        print("Result =", a / b)
    else:
        print("Cannot divide by zero")

else:
    print("Invalid operator")
# Out:
# Enter first number: 6
# Enter operator (+, -, *, /): *
# Enter second number: 8
# Result = 48.0

# %%
total_seconds = int(input("Enter total seconds: "))
hours = total_seconds // 3600
remaining = total_seconds % 3600
minutes = remaining // 60
seconds = remaining % 60
print("Hours =", hours)
print("Minutes =", minutes)
print("Seconds =", seconds)
# Out:
# Enter total seconds: 500
# Hours = 0
# Minutes = 8
# Seconds = 20

# %%
#Swap two variables
a=int(input ("Enter a :"))
b=int(input("Enter b :"))
print("before swapping:")
a, b = b, a
print("After swapping:")
print("a=", a)
print("b=", b)
# Out:
# Enter a :354
# Enter b :35
# before swapping:
# After swapping:
# a= 35
# b= 354

# %%
a=float(input("Enter frist number"))
b=float(input("Enter second number"))
c=float(input("Enter third number"))
average = ( a + b + c)/3
print( "Average =", average)
# Out:
# Enter frist number3
# Enter second number7
# Enter third number28
# Average = 12.666666666666666

# %%
c=float(input("enter temperature in celsius:"))
F =(c * 9 / 5) +32
print(" temperature in Celsius =" ,F)
# Out:
# enter temperature in celsius:32
#  temperature in Celsius = 89.6

# %%
p = float(input("Enter principal amount: "))
r = float(input("Enter rate of interest: "))
t = float(input("Enter time: "))

si = (p * r * t) / 100

print("Simple Interest =", si)
# Out:
# Enter principal amount: 12000
# Enter rate of interest: 1.3
# Enter time: 1
# Simple Interest = 156.0

# %%
radius=float(input("Enter radius:"))
area=3.14 * radius *radius
print("Area od circle = ",area)
# Out:
# Enter radius:6
# Area od circle =  113.03999999999999

# %%
a=10
b=10
sum=a+b
print(sum)
# Out:
# 20

# %%
print("Sneha")
print("20")
print("REPALL")
print("DHANEKULA")
# Out:
# Sneha
# 20
# REPALL
# DHANEKULA
